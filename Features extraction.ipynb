# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import networkx as nx
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
from nltk import word_tokenize
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

# %%
df = pd.read_excel("facebook_vaccination_preprocessed.xlsx")
df = df.drop(["Unnamed: 0"],axis=1)

# %%
df
# Out:
#                                                      Text     Type  \
# 0       Кейт Міддлтон услід за чоловіком вакцинувалася...     Post
# 1       В мене все прекрасно. Не бачу причини для вакц...  Comment
# 2       ЯСЕН  ПЕНЬ:\nВАКЦИН  ОТ ОРЗ  НЕТ  И  БЫТЬ  НЕ ...     Post
# 3       ДЕЦ МОЗУ розмістив звіт про безпеку covid-щепл...   Repost
# 4       Андрій Ігнатов аналіз на антитіла беруть з кро...  Comment
# ...                                                   ...      ...
# 152046  , според The ​​New York Times, друг акушер-гин...   Repost
# 152047  Национальный консультативный совет по иммуниза...  Comment
# 152048  (first_aid)(stop_sign)(first_aid)(stop_sign)(f...  Comment
# 152049      Сергей ПерфильевМихаил Чаленко включите гугл.  Comment
# 152050  Також вакцинувався. Вважаю , що медичні праців...     Post
#
#         Emotional context              Author  Subscribers  \
# 0                       0         Igor Stasyk          419
# 1                       1         Maryan Lviv           17
# 2                       0     Irina Marchenko            0
# 3                       0        Анюта Сажина            0
# 4                      -1         Юля Павлина          472
# ...                   ...                 ...          ...
# 152046                  0      Игорь Палладин         4226
# 152047                  0   Natalia Lavrenova         6090
# 152048                 -1      Наталія Юськів          622
# 152049                  0  Александр Мирошник          342
# 152050                  1      Євген Скрипник         2095
#
#                                                    Target  Target Subscribers  \
# 0                     Трускавецька Міська Лікарня Friends                5721
# 1                                       Ruslana Lyzhychko              123124
# 2                                         Irina Marchenko                   0
# 3                                            Анюта Сажина                   0
# 4                                       Ruslana Lyzhychko              123124
# ...                                                   ...                 ...
# 152046                                     Игорь Палладин                4226
# 152047                  Los Solomas / Солом‘янський район               38051
# 152048                                Людоньки, порадьте!              362291
# 152049                              Будни Торецка/Украина               13654
# 152050  Лікарі та пацієнти разом. Поради, консультації...               78973
#
#         Timestamp
# 0          109431
# 1          109420
# 2          109416
# 3          109411
# 4          109393
# ...           ...
# 152046          3
# 152047          3
# 152048          2
# 152049          0
# 152050          0
#
# [152051 rows x 8 columns]

# %% [markdown]
# ## Exploring some case

# %%
df_case=df.loc[df["Author"]=="Anastasia Litvinova"]
df_case
# Out:
#                                                      Text               Type  \
# 109435  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 115856  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 117068  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 117304  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 118680  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 119751  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 119904  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 120749  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 121062  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 121079  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 121109  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 121213  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 121218  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 121227  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 121252  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 121274  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 121275  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 121277  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 121279  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 121281  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 121284  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 121286  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 121287  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 121289  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 121291  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 121292  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 121294  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 121296  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 121297  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 121299  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 121300  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 121305  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 121307  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 121308  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 121313  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 121315  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
# 121316  Ось цей 18-літній мажор, який ганяє по Києву н...  Доповнений репост
#
#         Emotional context               Author  Subscribers  \
# 109435                  0  Anastasia Litvinova         4716
# 115856                  0  Anastasia Litvinova         4716
# 117068                  0  Anastasia Litvinova         4716
# 117304                  0  Anastasia Litvinova         4716
# 118680                  0  Anastasia Litvinova         4716
# 119751                  0  Anastasia Litvinova         4716
# 119904                  0  Anastasia Litvinova         4716
# 120749                  0  Anastasia Litvinova         4716
# 121062                  0  Anastasia Litvinova         4716
# 121079                  0  Anastasia Litvinova         4716
# 121109                  0  Anastasia Litvinova         4716
# 121213                  0  Anastasia Litvinova         4716
# 121218                  0  Anastasia Litvinova         4716
# 121227                  0  Anastasia Litvinova         4716
# 121252                  0  Anastasia Litvinova         4716
# 121274                  0  Anastasia Litvinova         4716
# 121275                  0  Anastasia Litvinova         4716
# 121277                  0  Anastasia Litvinova         4716
# 121279                  0  Anastasia Litvinova         4716
# 121281                  0  Anastasia Litvinova         4716
# 121284                  0  Anastasia Litvinova         4716
# 121286                  0  Anastasia Litvinova         4716
# 121287                  0  Anastasia Litvinova         4716
# 121289                  0  Anastasia Litvinova         4716
# 121291                  0  Anastasia Litvinova         4716
# 121292                  0  Anastasia Litvinova         4716
# 121294                  0  Anastasia Litvinova         4716
# 121296                  0  Anastasia Litvinova         4716
# 121297                  0  Anastasia Litvinova         4716
# 121299                  0  Anastasia Litvinova         4716
# 121300                  0  Anastasia Litvinova         4716
# 121305                  0  Anastasia Litvinova         4716
# 121307                  0  Anastasia Litvinova         4716
# 121308                  0  Anastasia Litvinova         4716
# 121313                  0  Anastasia Litvinova         4716
# 121315                  0  Anastasia Litvinova         4716
# 121316                  0  Anastasia Litvinova         4716
#
#                                                    Target  Target Subscribers  \
# 109435                                        АНТИКВАРТАЛ                1858
# 115856                          Твій МАЙДАН - До ПЕРЕМОГИ               12057
# 117068                        МАЙДАН  Є  І  БУДЕ ЗАВЖДИ .                2745
# 117304                                     Зелений віслюк                 701
# 118680                           "УКРАЇНЦІ 25" Полтавщина                 628
# 119751                               Кропивницький Online                 384
# 119904                                        МОЇ БРОВАРИ               75014
# 120749                        #Я_ПОРОХОБОТ (пишаюсь цим!)               21241
# 121062                            Полтава,мій рідний край                1088
# 121079                                   Вибір Кременчука                 671
# 121109                                    ГРОМАДА ПОЛТАВА                6308
# 121213                           Свідки ЗЕленого балагану               11976
# 121218                             Не мій преЗЕдент ! ! !               28481
# 121227                                ЕВОЛЮЦІЯ СВІДОМОСТІ                6882
# 121252                                     Київ, УКРАЇНА!                 486
# 121274                                   25% За Порошенко                2365
# 121275                Ватяность, це не наша "форма життя"                6171
# 121277                              Спільнота ПОРОХОБОТІВ               16176
# 121279                                АнтиЛох (Зеленский)                1062
# 121281  Доборолась Україна до самого краю. Гірше ляха ...                9690
# 121284                  (Група підтримки штанів) ГІДРАНТ!                2293
# 121286                               Майдан - Без Цензури                 849
# 121287                                         Майдан 3.0                 716
# 121289                                        "КИЇВ-ІНФО"                9913
# 121291   Національний Майдан - Українська Революція Че...               18858
# 121292                        Полтавські Тротуарні Новини                5764
# 121294                                           Вата шоу               16448
# 121296                                             НОВИНИ               11130
# 121297                               Свободный Краматорск                4203
# 121299                                      Зупинити Юлю!               11421
# 121300                                         Франківськ               16652
# 121305                Новости дня|Кропивницкий|Кировоград                4370
# 121307                                            Свояки                  809
# 121308                    Кривой Рог- за Петра Порошенко!                 335
# 121313                         РЕВОЛЮЦІЯ ОЧИЩЕННЯ УКРАЇНИ                 566
# 121315       Інформаційний Майдан (Информационный Майдан)                 345
# 121316                                  Краматорськ за ЄС                 608
#
#         Timestamp
# 109435      15575
# 115856      14030
# 117068      13738
# 117304      13683
# 118680      12840
# 119751      12485
# 119904      12434
# 120749      12165
# 121062      12029
# 121079      12016
# 121109      11995
# 121213      11894
# 121218      11888
# 121227      11873
# 121252      11714
# 121274      11621
# 121275      11620
# 121277      11620
# 121279      11619
# 121281      11617
# 121284      11609
# 121286      11608
# 121287      11607
# 121289      11606
# 121291      11605
# 121292      11601
# 121294      11596
# 121296      11593
# 121297      11592
# 121299      11592
# 121300      11592
# 121305      11590
# 121307      11586
# 121308      11583
# 121313      11576
# 121315      11575
# 121316      11574

# %% [markdown]
# Features needed:
# 1. Activity frequency
# 2. Inactivity inertia
# 3. Out degree
# 4. Targets popularity
# 5. Katz centrality
# 6. Posts similarity
# 7. Self posting
# 8. Emotional context*
# 9. Commentary percentage

# %% [markdown]
# ### Creating weighted directed graph

# %%
df_graph = df[["Author","Target"]].groupby(["Author","Target"]).size().reset_index(name="weight")

# %%
df_graph
# Out:
#                                                   Author  \
# 0                                  "Європейська Україна"
# 1                                  "Європейська Україна"
# 2                    0512.com.ua - сайт города Николаева
# 3      0532.ua - сайт міста Полтави - новини, афіша, ...
# 4      05366.com.ua - новости, афиша, справочник пред...
# ...                                                  ...
# 35245                                   татьяна кучукова
# 35246                                        яков дядяев
# 35247                                       ірина кондур
# 35248                        • АТН • Харьков • Новости •
# 35249                              • Типовий Мирноград •
#
#                                                   Target  weight
# 0                                  "Європейська Україна"       7
# 1                          Чернігів UA | Перлина Полісся       1
# 2                    0512.com.ua - сайт города Николаева       7
# 3      0532.ua - сайт міста Полтави - новини, афіша, ...       7
# 4      05366.com.ua - новости, афиша, справочник пред...      32
# ...                                                  ...     ...
# 35245                                   татьяна кучукова       9
# 35246                                        яков дядяев      14
# 35247                                       ірина кондур       6
# 35248                        • АТН • Харьков • Новости •      41
# 35249                              • Типовий Мирноград •       6
#
# [35250 rows x 3 columns]

# %%
graph = nx.from_pandas_edgelist(df_graph,source="Author",target="Target",edge_attr=True,create_using=nx.DiGraph())

# %%
out_degrees = np.array(list(graph.out_degree()))

# %%
katz_centr = nx.katz_centrality(graph.reverse())

# %%
df_features = pd.DataFrame({"Author":out_degrees[:,0],"Out degree":out_degrees[:,1].astype(int),
                           "Katz centr":katz_centr.values()})
df_features = df_features.loc[df_features["Out degree"]>0]
df_features
# Out:
#                                                   Author  Out degree  \
# 0                                  "Європейська Україна"           2
# 2                    0512.com.ua - сайт города Николаева           1
# 3      0532.ua - сайт міста Полтави - новини, афіша, ...           1
# 4      05366.com.ua - новости, афиша, справочник пред...           1
# 5                     0564.ua - Сайт города Кривого Рога           2
# ...                                                  ...         ...
# 18902                                     сергей ахметов           1
# 18903                                   татьяна кучукова           1
# 18904                                        яков дядяев           1
# 18905                                       ірина кондур           1
# 18906                              • Типовий Мирноград •           1
#
#        Katz centr
# 0        0.007028
# 2        0.006389
# 3        0.006389
# 4        0.006389
# 5        0.007028
# ...           ...
# 18902    0.006389
# 18903    0.006389
# 18904    0.006389
# 18905    0.006389
# 18906    0.006389
#
# [11058 rows x 3 columns]

# %%
def getActivityPattern(group,model):
    times = np.array(group[1]["Timestamp"])
    period = (times[0]-times[-1])+1
    frequency = len(times)/period
    inactivity = [[times[i-1]-times[i]] for i in range(1,len(times))]
    model.fit(inactivity)
    inertia = model.inertia_
    return frequency,inertia

# %%
authors = []
frequencies = []
inertias = []
model = KMeans(n_clusters=2)

groups = df[["Author","Timestamp"]].groupby(["Author"])
for group in tqdm(groups):
    authors.append(group[0])
    f,i = getActivityPattern(group,model)
    frequencies.append(f)
    inertias.append(i)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 11058/11058 [06:17<00:00, 29.33it/s]

# %%
df_time = pd.DataFrame({"Author":authors,"Frequency":frequencies,"Inactivity_Inertia":inertias})
df_features = pd.merge(df_features,df_time,how="left",on=["Author"])

# %%
df_features.head()
# Out:
#                                               Author  Out degree  Katz centr  \
# 0                              "Європейська Україна"           2    0.007028
# 1                0512.com.ua - сайт города Николаева           1    0.006389
# 2  0532.ua - сайт міста Полтави - новини, афіша, ...           1    0.006389
# 3  05366.com.ua - новости, афиша, справочник пред...           1    0.006389
# 4                 0564.ua - Сайт города Кривого Рога           2    0.007028
#
#    Frequency  Inactivity_Inertia
# 0   0.000081        1.849707e+08
# 1   0.000076        1.814639e+08
# 2   0.000077        1.691258e+08
# 3   0.000676        3.112500e+07
# 4   0.000429        7.893394e+07

# %%
df_features["Inactivity_Inertia"] = MinMaxScaler().fit_transform(df_features["Inactivity_Inertia"].values.reshape(-1,1))

# %%
df_features.head()
# Out:
#                                               Author  Out degree  Katz centr  \
# 0                              "Європейська Україна"           2    0.007028
# 1                0512.com.ua - сайт города Николаева           1    0.006389
# 2  0532.ua - сайт міста Полтави - новини, афіша, ...           1    0.006389
# 3  05366.com.ua - новости, афиша, справочник пред...           1    0.006389
# 4                 0564.ua - Сайт города Кривого Рога           2    0.007028
#
#    Frequency  Inactivity_Inertia
# 0   0.000081            0.226993
# 1   0.000076            0.222689
# 2   0.000077            0.207548
# 3   0.000676            0.038196
# 4   0.000429            0.096866

# %%
# Posts similarity


def cosine(u, v):
    return np.dot(u, v) / (np.linalg.norm(u) * np.linalg.norm(v))

def docs_preprocess(texts):
    tokenized = []
    for text in tqdm(texts):
        tokenized.append(word_tokenize(str(text).lower()))
    
    return tokenized
    
def getSimilarity(data,model):
    vectors = []
    for text in data:
        preprocessed = word_tokenize(str(text).lower())
        vectors.append(model.infer_vector(preprocessed))
    similarities = []
    for i in range(len(vectors)):
        for j in range(i,len(vectors)):
            similarities.append(cosine(vectors[i],vectors[j]))
    return np.mean(similarities)

# %%
print("Training model...")
data = df["Text"]
texts = docs_preprocess(data)
print("Preprocessed")
tagged_data = [TaggedDocument(d, [i]) for i, d in enumerate(texts)]
print("Tagged")
modelDoc = Doc2Vec(tagged_data, vector_size = 20, window = 2, min_count = 1, epochs = 10)
print("Completed")
# Out:
# Training model...
# 100%|████████████████████████████████████████████████████████████████████████| 152051/152051 [01:13<00:00, 2059.12it/s]
# Preprocessed
# Tagged
# Completed

# %%
authors = []
similarities = []
print("Compute similarities...")
groups = df[["Author","Text"]].groupby(["Author"])
for group in tqdm(groups):
    authors.append(group[0])
    s = getSimilarity(group[1]["Text"],modelDoc)
    similarities.append(s)
# Out:
# Compute similarities...
# 100%|████████████████████████████████████████████████████████████████████████████| 11058/11058 [04:19<00:00, 42.67it/s]

# %%
df_sim = pd.DataFrame({"Author":authors,"Posts similarity":similarities})
df_features = pd.merge(df_features,df_sim,how="left",on=["Author"])
df_features.head()
# Out:
#                                               Author  Out degree  Katz centr  \
# 0                              "Європейська Україна"           2    0.007028
# 1                0512.com.ua - сайт города Николаева           1    0.006389
# 2  0532.ua - сайт міста Полтави - новини, афіша, ...           1    0.006389
# 3  05366.com.ua - новости, афиша, справочник пред...           1    0.006389
# 4                 0564.ua - Сайт города Кривого Рога           2    0.007028
#
#    Frequency  Inactivity_Inertia  Posts similarity
# 0   0.000081            0.226993          0.680074
# 1   0.000076            0.222689          0.534414
# 2   0.000077            0.207548          0.595434
# 3   0.000676            0.038196          0.318691
# 4   0.000429            0.096866          0.544309

# %%
# Targets mean number of subscribers
# Authors number of subscribers

authors = []
target_subscribers = []
subscribers = []
groups = df[["Author","Subscribers","Target Subscribers"]].groupby(["Author"])
for group in groups:
    authors.append(group[0])
    target_subscribers.append(np.mean(group[1]["Target Subscribers"])+1)
    subscribers.append(np.mean(group[1]["Subscribers"])+1)

# %%
df_subs = pd.DataFrame({"Author":authors,"Target Subscribers":np.log10(target_subscribers),"Subscribers":np.log10(subscribers)})
df_features = pd.merge(df_features,df_subs,how="left",on=["Author"])

# %%
df_features
# Out:
#                                                   Author  Out degree  \
# 0                                  "Європейська Україна"           2
# 1                    0512.com.ua - сайт города Николаева           1
# 2      0532.ua - сайт міста Полтави - новини, афіша, ...           1
# 3      05366.com.ua - новости, афиша, справочник пред...           1
# 4                     0564.ua - Сайт города Кривого Рога           2
# ...                                                  ...         ...
# 11053                                     сергей ахметов           1
# 11054                                   татьяна кучукова           1
# 11055                                        яков дядяев           1
# 11056                                       ірина кондур           1
# 11057                              • Типовий Мирноград •           1
#
#        Katz centr  Frequency  Inactivity_Inertia  Posts similarity  \
# 0        0.007028   0.000081            0.226993          0.680074
# 1        0.006389   0.000076            0.222689          0.534414
# 2        0.006389   0.000077            0.207548          0.595434
# 3        0.006389   0.000676            0.038196          0.318691
# 4        0.007028   0.000429            0.096866          0.544309
# ...           ...        ...                 ...               ...
# 11053    0.006389   0.000212            0.155005          0.443194
# 11054    0.006389   0.000137            0.123643          0.729746
# 11055    0.006389   0.000229            0.069707          0.567366
# 11056    0.006389   0.000209            0.018872          0.803657
# 11057    0.006389   0.000096            0.066206          0.512484
#
#        Target Subscribers  Subscribers
# 0                4.028149     3.569140
# 1                4.196425     4.196425
# 2                4.144419     4.144419
# 3                3.679519     3.679519
# 4                4.532544     4.539139
# ...                   ...          ...
# 11053            3.414137     3.414137
# 11054            1.892095     1.892095
# 11055            2.271842     2.271842
# 11056            0.000000     0.000000
# 11057            3.912275     3.912275
#
# [11058 rows x 8 columns]

# %%
# Mean Emotional context

authors = []
emotion = []
groups = df[["Author","Emotional context"]].groupby(["Author"])
for group in groups:
    authors.append(group[0])
    emotion.append(np.mean(group[1]["Emotional context"]))
    
df_emo = pd.DataFrame({"Author":authors,"Emotion":emotion})
df_features = pd.merge(df_features,df_emo,how="left",on=["Author"])
df_features.head()
# Out:
#                                               Author  Out degree  Katz centr  \
# 0                              "Європейська Україна"           2    0.007028
# 1                0512.com.ua - сайт города Николаева           1    0.006389
# 2  0532.ua - сайт міста Полтави - новини, афіша, ...           1    0.006389
# 3  05366.com.ua - новости, афиша, справочник пред...           1    0.006389
# 4                 0564.ua - Сайт города Кривого Рога           2    0.007028
#
#    Frequency  Inactivity_Inertia  Posts similarity  Target Subscribers  \
# 0   0.000081            0.226993          0.680074            4.028149
# 1   0.000076            0.222689          0.534414            4.196425
# 2   0.000077            0.207548          0.595434            4.144419
# 3   0.000676            0.038196          0.318691            3.679519
# 4   0.000429            0.096866          0.544309            4.532544
#
#    Subscribers   Emotion
# 0     3.569140  0.375000
# 1     4.196425  0.142857
# 2     4.144419  0.142857
# 3     3.679519  0.375000
# 4     4.539139  0.217391

# %%
# Visiting coefficient

authors = []
selfposts = []
outposts = []
totals = []
groups = df[["Author","Target"]].groupby(["Author"])
for g in tqdm(groups):
    authors.append(g[0])
    total = len(g[1])
    self = 0
    out = 0
    for pair in g[1].iterrows():
        if pair[1]["Author"] == pair[1]["Target"]:
            self += 1 
        else:
            out += 1
    selfposts.append(self)
    outposts.append(out)
    totals.append(total)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 11058/11058 [00:06<00:00, 1638.80it/s]

# %%
df_posts = pd.DataFrame({"Author":authors,"Total Posts":totals,"Selfposts":selfposts,"Outposts":outposts})
df_features = pd.merge(df_features,df_posts,how="left",on=["Author"])
df_features
# Out:
#                                                   Author  Out degree  \
# 0                                  "Європейська Україна"           2
# 1                    0512.com.ua - сайт города Николаева           1
# 2      0532.ua - сайт міста Полтави - новини, афіша, ...           1
# 3      05366.com.ua - новости, афиша, справочник пред...           1
# 4                     0564.ua - Сайт города Кривого Рога           2
# ...                                                  ...         ...
# 11053                                     сергей ахметов           1
# 11054                                   татьяна кучукова           1
# 11055                                        яков дядяев           1
# 11056                                       ірина кондур           1
# 11057                              • Типовий Мирноград •           1
#
#        Katz centr  Frequency  Inactivity_Inertia  Posts similarity  \
# 0        0.007028   0.000081            0.226993          0.680074
# 1        0.006389   0.000076            0.222689          0.534414
# 2        0.006389   0.000077            0.207548          0.595434
# 3        0.006389   0.000676            0.038196          0.318691
# 4        0.007028   0.000429            0.096866          0.544309
# ...           ...        ...                 ...               ...
# 11053    0.006389   0.000212            0.155005          0.443194
# 11054    0.006389   0.000137            0.123643          0.729746
# 11055    0.006389   0.000229            0.069707          0.567366
# 11056    0.006389   0.000209            0.018872          0.803657
# 11057    0.006389   0.000096            0.066206          0.512484
#
#        Target Subscribers  Subscribers   Emotion  Total Posts  Selfposts  \
# 0                4.028149     3.569140  0.375000            8          7
# 1                4.196425     4.196425  0.142857            7          7
# 2                4.144419     4.144419  0.142857            7          7
# 3                3.679519     3.679519  0.375000           32         32
# 4                4.532544     4.539139  0.217391           23         22
# ...                   ...          ...       ...          ...        ...
# 11053            3.414137     3.414137 -0.260870           23         23
# 11054            1.892095     1.892095 -0.444444            9          9
# 11055            2.271842     2.271842 -0.071429           14         14
# 11056            0.000000     0.000000  0.500000            6          6
# 11057            3.912275     3.912275  0.166667            6          6
#
#        Outposts
# 0             1
# 1             0
# 2             0
# 3             0
# 4             1
# ...         ...
# 11053         0
# 11054         0
# 11055         0
# 11056         0
# 11057         0
#
# [11058 rows x 12 columns]

# %%
df_features["Visiting coefficient"] = df_features["Outposts"]/(df_features["Outposts"]+df_features["Selfposts"])
df_features = df_features.drop(["Selfposts","Outposts"],axis=1)
df_features
# Out:
#                                                   Author  Out degree  \
# 0                                  "Європейська Україна"           2
# 1                    0512.com.ua - сайт города Николаева           1
# 2      0532.ua - сайт міста Полтави - новини, афіша, ...           1
# 3      05366.com.ua - новости, афиша, справочник пред...           1
# 4                     0564.ua - Сайт города Кривого Рога           2
# ...                                                  ...         ...
# 11053                                     сергей ахметов           1
# 11054                                   татьяна кучукова           1
# 11055                                        яков дядяев           1
# 11056                                       ірина кондур           1
# 11057                              • Типовий Мирноград •           1
#
#        Katz centr  Frequency  Inactivity_Inertia  Posts similarity  \
# 0        0.007028   0.000081            0.226993          0.680074
# 1        0.006389   0.000076            0.222689          0.534414
# 2        0.006389   0.000077            0.207548          0.595434
# 3        0.006389   0.000676            0.038196          0.318691
# 4        0.007028   0.000429            0.096866          0.544309
# ...           ...        ...                 ...               ...
# 11053    0.006389   0.000212            0.155005          0.443194
# 11054    0.006389   0.000137            0.123643          0.729746
# 11055    0.006389   0.000229            0.069707          0.567366
# 11056    0.006389   0.000209            0.018872          0.803657
# 11057    0.006389   0.000096            0.066206          0.512484
#
#        Target Subscribers  Subscribers   Emotion  Total Posts  \
# 0                4.028149     3.569140  0.375000            8
# 1                4.196425     4.196425  0.142857            7
# 2                4.144419     4.144419  0.142857            7
# 3                3.679519     3.679519  0.375000           32
# 4                4.532544     4.539139  0.217391           23
# ...                   ...          ...       ...          ...
# 11053            3.414137     3.414137 -0.260870           23
# 11054            1.892095     1.892095 -0.444444            9
# 11055            2.271842     2.271842 -0.071429           14
# 11056            0.000000     0.000000  0.500000            6
# 11057            3.912275     3.912275  0.166667            6
#
#        Commentary percentage  Visiting coefficient
# 0                   0.000000              0.125000
# 1                   0.000000              0.000000
# 2                   0.142857              0.000000
# 3                   0.000000              0.000000
# 4                   0.000000              0.043478
# ...                      ...                   ...
# 11053               0.000000              0.000000
# 11054               0.000000              0.000000
# 11055               0.071429              0.000000
# 11056               0.000000              0.000000
# 11057               0.000000              0.000000
#
# [11058 rows x 12 columns]

# %%
# Commentary percentage
authors = []
commentary_perc = []
groups = df[["Author","Type"]].groupby(["Author"])
for group in groups:
    authors.append(group[0])
    total = len(group[1])
    com = len(group[1].loc[group[1]["Type"]=="Comment"])
    commentary_perc.append(com/total)

# %%
df_com = pd.DataFrame({"Author":authors,"Commentary percentage":commentary_perc})
df_features = pd.merge(df_features,df_com,how="left",on=["Author"])
df_features
# Out:
#                                                   Author  Out degree  \
# 0                                  "Європейська Україна"           2
# 1                    0512.com.ua - сайт города Николаева           1
# 2      0532.ua - сайт міста Полтави - новини, афіша, ...           1
# 3      05366.com.ua - новости, афиша, справочник пред...           1
# 4                     0564.ua - Сайт города Кривого Рога           2
# ...                                                  ...         ...
# 11053                                     сергей ахметов           1
# 11054                                   татьяна кучукова           1
# 11055                                        яков дядяев           1
# 11056                                       ірина кондур           1
# 11057                              • Типовий Мирноград •           1
#
#        Katz centr  Frequency  Inactivity_Inertia  Posts similarity  \
# 0        0.007028   0.000081            0.226993          0.680074
# 1        0.006389   0.000076            0.222689          0.534414
# 2        0.006389   0.000077            0.207548          0.595434
# 3        0.006389   0.000676            0.038196          0.318691
# 4        0.007028   0.000429            0.096866          0.544309
# ...           ...        ...                 ...               ...
# 11053    0.006389   0.000212            0.155005          0.443194
# 11054    0.006389   0.000137            0.123643          0.729746
# 11055    0.006389   0.000229            0.069707          0.567366
# 11056    0.006389   0.000209            0.018872          0.803657
# 11057    0.006389   0.000096            0.066206          0.512484
#
#        Target Subscribers  Subscribers   Emotion  Total Posts  Selfposts  \
# 0                4.028149     3.569140  0.375000            8          7
# 1                4.196425     4.196425  0.142857            7          7
# 2                4.144419     4.144419  0.142857            7          7
# 3                3.679519     3.679519  0.375000           32         32
# 4                4.532544     4.539139  0.217391           23         22
# ...                   ...          ...       ...          ...        ...
# 11053            3.414137     3.414137 -0.260870           23         23
# 11054            1.892095     1.892095 -0.444444            9          9
# 11055            2.271842     2.271842 -0.071429           14         14
# 11056            0.000000     0.000000  0.500000            6          6
# 11057            3.912275     3.912275  0.166667            6          6
#
#        Outposts  Commentary percentage
# 0             1               0.000000
# 1             0               0.000000
# 2             0               0.142857
# 3             0               0.000000
# 4             1               0.000000
# ...         ...                    ...
# 11053         0               0.000000
# 11054         0               0.000000
# 11055         0               0.071429
# 11056         0               0.000000
# 11057         0               0.000000
#
# [11058 rows x 13 columns]

# %% [markdown]
# ### Filtering

# %%
#df_filtered = df_features.loc[df_features["Out degree"] > 2]
#df_filtered
# Out:
#                       Author  Out degree  Katz centr  Frequency  \
# 25         Abramycheva  Olga           4    0.008178   0.000154
# 28     Advocat Oleh Leontyev           4    0.009000   0.000150
# 29               Євген Магда           4    0.008590   0.000376
# 30            Артур Нискубин           5    0.009158   0.000122
# 31                   Al Kopt           3    0.007539   0.000133
# ...                      ...         ...         ...        ...
# 11028      Ярослав Иванченко           6    0.009328   0.000094
# 11030         Ярослав Коваль           5    0.008952   0.000155
# 11031      Ярослав Кондришин           3    0.007603   0.000278
# 11032         Ярослав Мудрий           9    0.010925   0.000140
# 11042     игорь владимирский           3    0.007780   0.000978
#
#        Inactivity_Inertia  Posts similarity  Target Subscribers  Subscribers  \
# 25               0.033380          0.551113            4.945640     2.037426
# 28               0.121900          0.311276            3.935343     3.449941
# 29               0.111423          0.467046            4.228020     4.289901
# 30               0.092905          0.518000            4.163293     4.021933
# 31               0.231999          0.434548            5.637169     0.000000
# ...                   ...               ...                 ...          ...
# 11028            0.112010          0.439195            5.973920     2.693727
# 11030            0.101151          0.511693            4.823154     0.000000
# 11031            0.294026          0.399642            5.562610     2.089905
# 11032            0.020738          0.863573            4.851476     1.106455
# 11042            0.000964          0.523630            4.513823     1.903090
#
#         Emotion  Total Posts  Visiting coefficient  Commentary percentage
# 25     0.333333            6              1.000000               1.000000
# 28    -0.125000            8              0.625000               0.625000
# 29    -0.230769           26              0.153846               0.615385
# 30     0.000000            7              0.714286               0.714286
# 31    -0.214286           14              1.000000               1.000000
# ...         ...          ...                   ...                    ...
# 11028 -0.428571            7              1.000000               1.000000
# 11030  0.500000            8              1.000000               0.625000
# 11031 -0.222222           18              1.000000               1.000000
# 11032 -0.555556            9              1.000000               0.111111
# 11042 -0.166667            6              1.000000               1.000000
#
# [4845 rows x 12 columns]

# %% [markdown]
# ### Saving

# %%
df_features.to_excel("facebook_features.xlsx")
